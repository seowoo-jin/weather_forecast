# %%
import pickle

with open('result_model_fold/Swanton_OH/Xgboost_model_with_Swanton_OH.pkl', 'rb') as f:
    print(f)
    data = pickle.load(f)
# Out:
# <_io.BufferedReader name='result_model_fold/Swanton_OH/Xgboost_model_with_Swanton_OH.pkl'>

# %%
from enums.enums import Model
print(data[Model.MODEL])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)

# %%
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)

# %%
from enums.enums import Model, Date, Data, Rmse
type(data[Data.PREDICTED_OUTPUT_DATA])
# Out:
# numpy.ndarray

# %%
data[Data.PREDICTED_OUTPUT_DATA]
# Out:
# array([[28.504316, 15.266671, 11.974587],
#        [28.410843, 16.12422 , 14.991864],
#        [28.036793, 18.176905, 17.21363 ],
#        ...,
#        [27.177668, 17.56768 , 11.101653],
#        [30.370852, 19.853838, 21.914112],
#        [30.420568, 17.696596, 14.642359]], dtype=float32)

# %%
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA], data[Data.TEST_OUTPUT_DATA].columns)
