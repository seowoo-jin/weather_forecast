# %%
import pickle
with open('result_model/Swanton_OH/RF_model_with_Swanton_OH.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
from enums.enums import Model
print(data[Model.MODEL.value])
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=3, n_estimators=300,
#                       random_state=0)

# %%
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)

# %%
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)

# %%
from enums.enums import Model, Date, Data, Rmse
type(data[Data.PREDICTED_OUTPUT_DATA.value])
# Out:
# pandas.core.frame.DataFrame

# %%
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA.value].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA.value].to_numpy(), data[Data.TEST_OUTPUT_DATA.value].columns)
