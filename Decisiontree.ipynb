# %%
import pickle
with open('result_model/Swanton_OH/DecisionTree_model_with_Swanton_OH.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
from enums.enums import Model
print(data[Model.MODEL.value])
# Out:
# Pipeline(steps=[('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=8, min_samples_leaf=20,
#                                        random_state=2021))])

# %%
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)

# %%
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)

# %%
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA.value].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA.value], data[Data.TEST_OUTPUT_DATA.value].columns)
