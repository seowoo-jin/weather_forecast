# %%
import pickle
with open('best_rf_model_with_data.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)

# %%
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)

# %%
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA.value].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA.value].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA.value].columns)
