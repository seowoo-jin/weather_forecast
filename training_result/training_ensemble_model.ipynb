# %%
import os
import math
import pickle
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn

from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import VotingRegressor
import xgboost
from itertools import combinations
from torch.utils.data import DataLoader, TensorDataset

from utils.weather_api import WeatherApi
from utils.common_function import splitData
from enums.enums import Model, Date, Data, Rmse
from sklearn.metrics import accuracy_score
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import Ridge
import itertools

weatherApi = WeatherApi();
area = 'Billings_MT'
# Swanton_OH
X, y = weatherApi.get_weather_data_from_excel(area)
X_train, X_test, y_train, y_test = splitData(X, y, 365)

# MinMaxScaler 적용
scaler = MinMaxScaler()
if 'date' in X_train.columns:
    X_train = X_train.drop(columns=['date'])
    X_test = X_test.drop(columns=['date'])
if 'date' in y_train.columns[0]:
    y_train = y_train.drop(columns=[y_train.columns[0]])
    y_test = y_test.drop(columns=[y_test.columns[0]])

# MinMaxScaler 적용
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

date_range = pd.date_range(start='2023-08-01', end='2024-07-30')
date_df = pd.DataFrame(date_range, columns=['date'])

# %%
with open(f'result_model_fold/{area}/MLP_model_with_{area}.pkl', 'rb') as f:
    mlp = pickle.load(f)
mlp_model = mlp[Model.MODEL]

with open(f'result_model_fold/{area}/RF_model_with_{area}.pkl', 'rb') as f:
    rf = pickle.load(f)
rf_model = rf[Model.MODEL]

with open(f'result_model_fold/{area}/ExtraTree_model_with_{area}.pkl', 'rb') as f:
    extra = pickle.load(f)
extra_model = extra[Model.MODEL]

with open(f'result_model_fold/{area}/DecisionTree_model_with_{area}.pkl', 'rb') as f:
    decision = pickle.load(f)
decision_model = decision[Model.MODEL]

with open(f'result_model_fold/{area}/GradientBoosting_model_with_{area}.pkl', 'rb') as f:
    gradient = pickle.load(f)
gradient_model = gradient[Model.MODEL]

with open(f'result_model_fold/{area}/Xgboost_model_with_{area}.pkl', 'rb') as f:
    xgboost_ = pickle.load(f)
xgboost_model = xgboost_[Model.MODEL]

# %%
estimators = [
    ('RF', rf_model),
    ('EXTRA', extra_model),
    ('MLP', mlp_model),
    ('DT', decision_model),
    ('XG', xgboost_model)
]
combination_result = []
for r in range(2, len(estimators) + 1):  # 2개부터 모든 모델 조합까지 생성
    combi = list(itertools.combinations(estimators, r))
    combination_result.extend(combi)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_cnt = 0

for subset in combination_result:

    best_valid_rmse = 100
    for train_index, val_index in kf.split(X_train_scaled):
        X_train_fold, X_val_fold = X_train_scaled.iloc[train_index], X_train_scaled.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        fold_cnt += 1
        # Stacking 모델 생성
        stacking_regressor = StackingRegressor(
            estimators=list(subset),
            final_estimator=Ridge()
        )
        multi_output_staking_reg = MultiOutputRegressor(stacking_regressor)

        # 모델 학습
        multi_output_staking_reg.fit(X_train_fold, y_train_fold)

        # 예측 및 평가
        y_pred_stack = multi_output_staking_reg.predict(X_val_fold)
        stacking_val_rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_stack))

        if stacking_val_rmse < best_valid_rmse:
            best_valid_rmse = stacking_val_rmse
            staking_best_model = multi_output_staking_reg
            staking_best_train_input = X_train_fold
            staking_best_train_output = y_train_fold
            staking_best_valid_input = X_val_fold
            staking_best_valid_output = y_val_fold
            print(f'best rmse : {best_valid_rmse}')

    staking_pred = staking_best_model.predict(X_test_scaled)

    data_to_save = {
        Model.MODEL: staking_best_model,
        Data.TRAIN_INPUT_DATA: staking_best_train_input,
        Data.TRAIN_OUTPUT_DATA: staking_best_train_output,
        Data.VALID_INPUT_DATA: staking_best_valid_input,
        Data.VALID_OUTPUT_DATA: staking_best_valid_output,
        Data.TEST_INPUT_DATA: X_test_scaled,
        Data.TEST_OUTPUT_DATA: y_test,
        Data.PREDICTED_OUTPUT_DATA: staking_pred,
        Rmse.BEST_RMSE: np.sqrt(mean_squared_error(staking_pred, y_test)),
        Date.DATE: date_df,
    }

    # 조합 이름 생성 (모델 이름을 이어붙임)
    model_names = '_'.join([name for name, _ in subset])

    # 경로 및 파일 이름 설정
    path = f'result_model_fold/{area}'
    file_path = f'{path}/Stacking_{model_names}_model_with_{area}.pkl'

    # 디렉토리 생성 및 파일 저장
    os.makedirs(path, exist_ok=True)
    with open(file_path, 'wb') as f:
        pickle.dump(data_to_save, f)

    print(f'Model saved to {file_path} with RMSE: {np.sqrt(mean_squared_error(staking_pred, y_test))}')
# Out:
# best rmse : 4.216872181316406
# best rmse : 4.090378873192463
# best rmse : 4.078903988002115
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_model_with_Billings_MT.pkl with RMSE: 3.934777712875744
# best rmse : 4.094934497704948
# best rmse : 4.013688640784395
# best rmse : 3.998672481087394
# Model saved to result_model_fold/Billings_MT/Stacking_RF_MLP_model_with_Billings_MT.pkl with RMSE: 3.856083906130833
# best rmse : 4.205439138911264
# best rmse : 4.076724824576408
# best rmse : 4.059485787845395
# Model saved to result_model_fold/Billings_MT/Stacking_RF_DT_model_with_Billings_MT.pkl with RMSE: 3.9328884125349632
# best rmse : 4.061077777673172
# best rmse : 3.9702848607466685
# best rmse : 3.9023485577892525
# Model saved to result_model_fold/Billings_MT/Stacking_RF_XG_model_with_Billings_MT.pkl with RMSE: 3.8503986962964305
# best rmse : 4.121687043384589
# best rmse : 4.08133468169527
# best rmse : 4.06942398544808
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_MLP_model_with_Billings_MT.pkl with RMSE: 3.9025133141217987
# best rmse : 4.293348703709972
# best rmse : 4.1810959971542605
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_DT_model_with_Billings_MT.pkl with RMSE: 4.025618367471086
# best rmse : 4.057407724058376
# best rmse : 3.971981839679318
# best rmse : 3.921736560364911
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_XG_model_with_Billings_MT.pkl with RMSE: 3.8567086565397353
# best rmse : 4.13269254661782
# best rmse : 4.0988194007641665
# Model saved to result_model_fold/Billings_MT/Stacking_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.908790904855391
# best rmse : 3.9879546401855457
# best rmse : 3.964643341433474
# best rmse : 3.8847599980252974
# Model saved to result_model_fold/Billings_MT/Stacking_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.805961583893799
# best rmse : 4.086418234610768
# best rmse : 4.02897676665476
# best rmse : 3.9158090580890446
# Model saved to result_model_fold/Billings_MT/Stacking_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.888280875473442
# best rmse : 4.096287945678998
# best rmse : 4.01425591887834
# best rmse : 4.003982022125503
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_MLP_model_with_Billings_MT.pkl with RMSE: 3.8520634990156797
# best rmse : 4.2088078528843
# best rmse : 4.0769685365023545
# best rmse : 4.0708753230430155
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_DT_model_with_Billings_MT.pkl with RMSE: 3.936079713620055
# best rmse : 4.063732811800913
# best rmse : 3.966697787803057
# best rmse : 3.9139501573377538
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_XG_model_with_Billings_MT.pkl with RMSE: 3.853303056680304
# best rmse : 4.091585260564211
# best rmse : 4.0024649479831504
# best rmse : 3.9977178317689304
# Model saved to result_model_fold/Billings_MT/Stacking_RF_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.862390615276574
# best rmse : 3.999120642502883
# best rmse : 3.936104836808493
# best rmse : 3.8804103087757325
# Model saved to result_model_fold/Billings_MT/Stacking_RF_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.8001414109445104
# best rmse : 4.057794389755587
# best rmse : 3.961190324384234
# best rmse : 3.898475034618345
# Model saved to result_model_fold/Billings_MT/Stacking_RF_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.853725107267849
# best rmse : 4.1228473781251775
# best rmse : 4.078522922829985
# best rmse : 4.070357756191518
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.9027301574703728
# best rmse : 3.994766477867602
# best rmse : 3.942591015705091
# best rmse : 3.894866368563492
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.8015471690410294
# best rmse : 4.057456244713603
# best rmse : 3.96673711761467
# best rmse : 3.920553644227827
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.8606981823195454
# best rmse : 3.9900633881863645
# best rmse : 3.965781942621126
# best rmse : 3.883437508134662
# Model saved to result_model_fold/Billings_MT/Stacking_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.803545480113197
# best rmse : 4.092382887650807
# best rmse : 4.002973759460005
# best rmse : 4.002654062528433
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.8575988647215373
# best rmse : 4.0025961061507624
# best rmse : 3.9362557981386335
# best rmse : 3.889210150094374
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.80011365132554
# best rmse : 4.059501947927094
# best rmse : 3.95791852096166
# best rmse : 3.91021245894924
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.8558971259085295
# best rmse : 3.9971047938664492
# best rmse : 3.928183643760827
# best rmse : 3.8794810687917107
# Model saved to result_model_fold/Billings_MT/Stacking_RF_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.8049822775700397
# best rmse : 3.994564066721197
# best rmse : 3.938306193419969
# best rmse : 3.8954694028924393
# Model saved to result_model_fold/Billings_MT/Stacking_EXTRA_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.805293153547241
# best rmse : 4.000074211817673
# best rmse : 3.9282910746743758
# best rmse : 3.888186238114951
# Model saved to result_model_fold/Billings_MT/Stacking_RF_EXTRA_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.8044841707251087

# %%
estimators = [
    ('RF', rf_model),
    ('EXTRA', extra_model),
    ('MLP', mlp_model),
    ('DT', decision_model),
    ('XG', xgboost_model)
]
combination_result = []
for r in range(2, len(estimators) + 1):  # 2개부터 모든 모델 조합까지 생성
    combi = list(itertools.combinations(estimators, r))
    combination_result.extend(combi)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_cnt = 0

for subset in combination_result:

    best_valid_rmse = 100
    for train_index, val_index in kf.split(X_train_scaled):
        X_train_fold, X_val_fold = X_train_scaled.iloc[train_index], X_train_scaled.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        fold_cnt += 1
        # Stacking 모델 생성
        voting_regressor = VotingRegressor(
            estimators=list(subset)
        )
        multi_output_voting_reg = MultiOutputRegressor(voting_regressor)

        # 모델 학습
        multi_output_voting_reg.fit(X_train_fold, y_train_fold)

        # 예측 및 평가
        y_pred_valid = multi_output_voting_reg.predict(X_val_fold)
        voting_val_rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_valid))

        if voting_val_rmse < best_valid_rmse:
            best_valid_rmse = voting_val_rmse
            voting_best_model = multi_output_voting_reg
            voting_best_train_input = X_train_fold
            voting_best_train_output = y_train_fold
            voting_best_valid_input = X_val_fold
            voting_best_valid_output = y_val_fold
            print(f'best rmse : {best_valid_rmse}')

    voting_pred = voting_best_model.predict(X_test_scaled)

    data_to_save = {
        Model.MODEL: voting_best_model,
        Data.TRAIN_INPUT_DATA: voting_best_train_input,
        Data.TRAIN_OUTPUT_DATA: voting_best_train_output,
        Data.VALID_INPUT_DATA: voting_best_valid_input,
        Data.VALID_OUTPUT_DATA: voting_best_valid_output,
        Data.TEST_INPUT_DATA: X_test_scaled,
        Data.TEST_OUTPUT_DATA: y_test,
        Data.PREDICTED_OUTPUT_DATA: voting_pred,
        Rmse.BEST_RMSE: np.sqrt(mean_squared_error(voting_pred, y_test)),
        Date.DATE: date_df,
    }

    # 조합 이름 생성 (모델 이름을 이어붙임)
    model_names = '_'.join([name for name, _ in subset])

    # 경로 및 파일 이름 설정
    path = f'result_model_fold/{area}'
    file_path = f'{path}/Voting_{model_names}_model_with_{area}.pkl'

    # 디렉토리 생성 및 파일 저장
    os.makedirs(path, exist_ok=True)
    with open(file_path, 'wb') as f:
        pickle.dump(data_to_save, f)

    print(f'Model saved to {file_path} with RMSE: {np.sqrt(mean_squared_error(voting_pred, y_test))}')
# Out:
# best rmse : 4.247993066019048
# best rmse : 4.156427678242443
# best rmse : 4.113874654100805
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_model_with_Billings_MT.pkl with RMSE: 3.9637343940913854
# best rmse : 4.0707539592966935
# best rmse : 4.067568261810283
# best rmse : 4.01269783812103
# Model saved to result_model_fold/Billings_MT/Voting_RF_MLP_model_with_Billings_MT.pkl with RMSE: 3.8338326490560823
# best rmse : 4.479538548685196
# best rmse : 4.390276536330472
# best rmse : 4.3214918447280475
# Model saved to result_model_fold/Billings_MT/Voting_RF_DT_model_with_Billings_MT.pkl with RMSE: 4.118512593828836
# best rmse : 4.070977092632914
# best rmse : 3.986696658284135
# best rmse : 3.9243846094022556
# Model saved to result_model_fold/Billings_MT/Voting_RF_XG_model_with_Billings_MT.pkl with RMSE: 3.851249008386004
# best rmse : 4.115003089102939
# best rmse : 4.073476133406808
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_MLP_model_with_Billings_MT.pkl with RMSE: 3.887771721263036
# best rmse : 4.514200411512161
# best rmse : 4.431430975078317
# best rmse : 4.355692775870657
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_DT_model_with_Billings_MT.pkl with RMSE: 4.159001882307072
# best rmse : 4.089760310871983
# best rmse : 4.015510223514861
# best rmse : 3.9548653678224657
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_XG_model_with_Billings_MT.pkl with RMSE: 3.8717284781773795
# best rmse : 4.315414418041964
# best rmse : 4.240344042324542
# Model saved to result_model_fold/Billings_MT/Voting_MLP_DT_model_with_Billings_MT.pkl with RMSE: 4.00823033601873
# best rmse : 3.9776654530432847
# best rmse : 3.9698680223478897
# best rmse : 3.9073802259562678
# Model saved to result_model_fold/Billings_MT/Voting_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.7953183229079976
# best rmse : 4.325412996979363
# best rmse : 4.2554069752471415
# best rmse : 4.170135727416398
# Model saved to result_model_fold/Billings_MT/Voting_DT_XG_model_with_Billings_MT.pkl with RMSE: 4.028655990551252
# best rmse : 4.119861523369235
# best rmse : 4.092244308161811
# best rmse : 4.040896835386193
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_MLP_model_with_Billings_MT.pkl with RMSE: 3.866581307742588
# best rmse : 4.37227497396523
# best rmse : 4.283306068165831
# best rmse : 4.218121994547536
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_DT_model_with_Billings_MT.pkl with RMSE: 4.037370139878009
# best rmse : 4.1114612169596185
# best rmse : 4.0271108479059725
# best rmse : 3.9714252873739317
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_XG_model_with_Billings_MT.pkl with RMSE: 3.869503294633591
# best rmse : 4.2278605986034785
# best rmse : 4.199227763193277
# best rmse : 4.127547981858989
# Model saved to result_model_fold/Billings_MT/Voting_RF_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.9213808791186855
# best rmse : 4.005034587638515
# best rmse : 3.9674741158673754
# best rmse : 3.9103803510094806
# Model saved to result_model_fold/Billings_MT/Voting_RF_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.786401382652444
# best rmse : 4.235104151207608
# best rmse : 4.154099364788612
# best rmse : 4.079314536265565
# Model saved to result_model_fold/Billings_MT/Voting_RF_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.9405735549593857
# best rmse : 4.2509590632792085
# best rmse : 4.23234504833005
# best rmse : 4.154757735958459
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.9496414283923027
# best rmse : 4.020662307847383
# best rmse : 3.9951472466738362
# best rmse : 3.935896012757239
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.805340119844472
# best rmse : 4.247245946022344
# best rmse : 4.170397261961686
# best rmse : 4.093223476709497
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.9542059103919707
# best rmse : 4.129223705148534
# best rmse : 4.103878697365412
# best rmse : 4.024683866622628
# Model saved to result_model_fold/Billings_MT/Voting_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.86036615891816
# best rmse : 4.218441353256768
# best rmse : 4.176366976006066
# best rmse : 4.10937449905231
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_MLP_DT_model_with_Billings_MT.pkl with RMSE: 3.9176426069685606
# best rmse : 4.048711206772663
# best rmse : 4.00312378664514
# best rmse : 3.9480700932181394
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_MLP_XG_model_with_Billings_MT.pkl with RMSE: 3.8142629986737275
# best rmse : 4.21786453020077
# best rmse : 4.1346536843388035
# best rmse : 4.065271168579647
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.925818888198475
# best rmse : 4.12000893366133
# best rmse : 4.0753771563319825
# best rmse : 4.004515821435222
# Model saved to result_model_fold/Billings_MT/Voting_RF_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.8455362408553766
# best rmse : 4.130936386496862
# best rmse : 4.092837471538249
# best rmse : 4.01903718156808
# Model saved to result_model_fold/Billings_MT/Voting_EXTRA_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.858759156703451
# best rmse : 4.132202274046291
# best rmse : 4.08070991434988
# best rmse : 4.0132960037353484
# Model saved to result_model_fold/Billings_MT/Voting_RF_EXTRA_MLP_DT_XG_model_with_Billings_MT.pkl with RMSE: 3.85625340428706

# %%
weatherApi = WeatherApi();
area = 'Swanton_OH'
# Swanton_OH
X, y = weatherApi.get_weather_data_from_excel(area)
X_train, X_test, y_train, y_test = splitData(X, y, 365)

# MinMaxScaler 적용
scaler = MinMaxScaler()
if 'date' in X_train.columns:
    X_train = X_train.drop(columns=['date'])
    X_test = X_test.drop(columns=['date'])
if 'date' in y_train.columns[0]:
    y_train = y_train.drop(columns=[y_train.columns[0]])
    y_test = y_test.drop(columns=[y_test.columns[0]])

# MinMaxScaler 적용
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

date_range = pd.date_range(start='2023-08-01', end='2024-07-30')
date_df = pd.DataFrame(date_range, columns=['date'])

# %%
with open(f'result_model_fold/{area}/MLP_model_with_{area}.pkl', 'rb') as f:
    mlp = pickle.load(f)
mlp_model = mlp[Model.MODEL]

with open(f'result_model_fold/{area}/RF_model_with_{area}.pkl', 'rb') as f:
    rf = pickle.load(f)
rf_model = rf[Model.MODEL]

with open(f'result_model_fold/{area}/ExtraTree_model_with_{area}.pkl', 'rb') as f:
    extra = pickle.load(f)
extra_model = extra[Model.MODEL]

with open(f'result_model_fold/{area}/DecisionTree_model_with_{area}.pkl', 'rb') as f:
    decision = pickle.load(f)
decision_model = decision[Model.MODEL]

with open(f'result_model_fold/{area}/GradientBoosting_model_with_{area}.pkl', 'rb') as f:
    gradient = pickle.load(f)
gradient_model = gradient[Model.MODEL]

with open(f'result_model_fold/{area}/Xgboost_model_with_{area}.pkl', 'rb') as f:
    xgboost_ = pickle.load(f)
xgboost_model = xgboost_[Model.MODEL]

# %%
estimators = [
    ('RF', rf_model),
    ('EXTRA', extra_model),
    ('MLP', mlp_model),
    ('DT', decision_model),
    ('XG', xgboost_model)
]
combination_result = []
for r in range(2, len(estimators) + 1):  # 2개부터 모든 모델 조합까지 생성
    combi = list(itertools.combinations(estimators, r))
    combination_result.extend(combi)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_cnt = 0

for subset in combination_result:

    best_valid_rmse = 100
    for train_index, val_index in kf.split(X_train_scaled):
        X_train_fold, X_val_fold = X_train_scaled.iloc[train_index], X_train_scaled.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        fold_cnt += 1
        # Stacking 모델 생성
        stacking_regressor = StackingRegressor(
            estimators=list(subset),
            final_estimator=Ridge()
        )
        multi_output_staking_reg = MultiOutputRegressor(stacking_regressor)

        # 모델 학습
        multi_output_staking_reg.fit(X_train_fold, y_train_fold)

        # 예측 및 평가
        y_pred_stack = multi_output_staking_reg.predict(X_val_fold)
        stacking_val_rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_stack))

        if stacking_val_rmse < best_valid_rmse:
            best_valid_rmse = stacking_val_rmse
            staking_best_model = multi_output_staking_reg
            staking_best_train_input = X_train_fold
            staking_best_train_output = y_train_fold
            staking_best_valid_input = X_val_fold
            staking_best_valid_output = y_val_fold
            print(f'best rmse : {best_valid_rmse}')

    staking_pred = staking_best_model.predict(X_test_scaled)

    data_to_save = {
        Model.MODEL: staking_best_model,
        Data.TRAIN_INPUT_DATA: staking_best_train_input,
        Data.TRAIN_OUTPUT_DATA: staking_best_train_output,
        Data.VALID_INPUT_DATA: staking_best_valid_input,
        Data.VALID_OUTPUT_DATA: staking_best_valid_output,
        Data.TEST_INPUT_DATA: X_test_scaled,
        Data.TEST_OUTPUT_DATA: y_test,
        Data.PREDICTED_OUTPUT_DATA: staking_pred,
        Rmse.BEST_RMSE: np.sqrt(mean_squared_error(staking_pred, y_test)),
        Date.DATE: date_df,
    }

    # 조합 이름 생성 (모델 이름을 이어붙임)
    model_names = '_'.join([name for name, _ in subset])

    # 경로 및 파일 이름 설정
    path = f'result_model_fold/{area}'
    file_path = f'{path}/Stacking_{model_names}_model_with_{area}.pkl'

    # 디렉토리 생성 및 파일 저장
    os.makedirs(path, exist_ok=True)
    with open(file_path, 'wb') as f:
        pickle.dump(data_to_save, f)

    print(f'Model saved to {file_path} with RMSE: {np.sqrt(mean_squared_error(staking_pred, y_test))}')
# Out:
# best rmse : 3.027926285082374
# best rmse : 3.0109406880849097
# best rmse : 2.9155140871373493
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_model_with_Swanton_OH.pkl with RMSE: 3.019457145125462
# best rmse : 2.970238119545359
# best rmse : 2.942872723024058
# best rmse : 2.8309364174265883
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_MLP_model_with_Swanton_OH.pkl with RMSE: 2.9738864722399194
# best rmse : 3.04092671151163
# best rmse : 3.014962640347045
# best rmse : 2.9124831656169072
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_DT_model_with_Swanton_OH.pkl with RMSE: 3.0160744802330974
# best rmse : 2.9378859689854115
# best rmse : 2.931587840033816
# best rmse : 2.82511668874899
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_XG_model_with_Swanton_OH.pkl with RMSE: 2.9572119755062283
# best rmse : 3.0511010710333473
# best rmse : 2.991570609067504
# best rmse : 2.8777729224891386
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_MLP_model_with_Swanton_OH.pkl with RMSE: 3.055103416125836
# best rmse : 3.1590819692964427
# best rmse : 3.0849761902745962
# best rmse : 3.0077211272858317
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_DT_model_with_Swanton_OH.pkl with RMSE: 3.133304039092896
# best rmse : 2.9629585151115174
# best rmse : 2.938245905133633
# best rmse : 2.8303575880092646
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_XG_model_with_Swanton_OH.pkl with RMSE: 2.9736411965627148
# best rmse : 3.051250943426904
# best rmse : 3.000907910956034
# best rmse : 2.9207943370568237
# Model saved to result_model_fold/Swanton_OH/Stacking_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.0945382663337453
# best rmse : 2.913478737335878
# best rmse : 2.901056423389076
# best rmse : 2.7887054648482996
# Model saved to result_model_fold/Swanton_OH/Stacking_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9560589712831593
# best rmse : 2.9819540654354295
# best rmse : 2.97377621789483
# best rmse : 2.874196661763104
# Model saved to result_model_fold/Swanton_OH/Stacking_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.999880528566694
# best rmse : 2.9508983591709037
# best rmse : 2.932091671008998
# best rmse : 2.8215658641326384
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_MLP_model_with_Swanton_OH.pkl with RMSE: 2.9734847620162954
# best rmse : 3.0306678364264887
# best rmse : 3.008940965082842
# best rmse : 2.9111490245649136
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_DT_model_with_Swanton_OH.pkl with RMSE: 3.0160052006341864
# best rmse : 2.93164232142155
# best rmse : 2.926845792724912
# best rmse : 2.8230889033869553
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_XG_model_with_Swanton_OH.pkl with RMSE: 2.957691537086132
# best rmse : 2.9734250589851303
# best rmse : 2.9422241828368962
# best rmse : 2.829081741959089
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 2.9726478606951234
# best rmse : 2.904670324713136
# best rmse : 2.892751732905253
# best rmse : 2.7804611159986035
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9408495547643354
# best rmse : 2.940838463130463
# best rmse : 2.9302533733931093
# best rmse : 2.8223689034440995
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.955041625395739
# best rmse : 3.0428489042122138
# best rmse : 2.983181730221733
# best rmse : 2.880867292001006
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.056502329556385
# best rmse : 2.918974552276375
# best rmse : 2.8989639834313725
# best rmse : 2.784850953923464
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9577263464599035
# best rmse : 2.9638145072829523
# best rmse : 2.9375822564877074
# best rmse : 2.8324708297862298
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.97444088902704
# best rmse : 2.915604315260179
# best rmse : 2.8987566374484435
# best rmse : 2.791132150216961
# Model saved to result_model_fold/Swanton_OH/Stacking_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.956221444785606
# best rmse : 2.95442118730393
# best rmse : 2.931049061868394
# best rmse : 2.819321105462229
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 2.971916435202323
# best rmse : 2.891226718760769
# best rmse : 2.8859849038883567
# best rmse : 2.77659099790945
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.941820149400988
# best rmse : 2.9348310887500313
# best rmse : 2.925241193817182
# best rmse : 2.8204340287097938
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.9555316904130677
# best rmse : 2.9080383458096843
# best rmse : 2.8920501517957127
# best rmse : 2.7792395592446213
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.939933585762884
# best rmse : 2.91964455589921
# best rmse : 2.8979706494825064
# best rmse : 2.787489518963709
# Model saved to result_model_fold/Swanton_OH/Stacking_EXTRA_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.959118389629684
# best rmse : 2.8948880097618575
# best rmse : 2.8849700196702956
# best rmse : 2.7751699943109434
# Model saved to result_model_fold/Swanton_OH/Stacking_RF_EXTRA_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 2.940696302749332

# %%
estimators = [
    ('RF', rf_model),
    ('EXTRA', extra_model),
    ('MLP', mlp_model),
    ('DT', decision_model),
    ('XG', xgboost_model)
]
combination_result = []
for r in range(2, len(estimators) + 1):  # 2개부터 모든 모델 조합까지 생성
    combi = list(itertools.combinations(estimators, r))
    combination_result.extend(combi)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_cnt = 0

for subset in combination_result:

    best_valid_rmse = 100
    for train_index, val_index in kf.split(X_train_scaled):
        X_train_fold, X_val_fold = X_train_scaled.iloc[train_index], X_train_scaled.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        fold_cnt += 1
        # Stacking 모델 생성
        voting_regressor = VotingRegressor(
            estimators=list(subset)
        )
        multi_output_voting_reg = MultiOutputRegressor(voting_regressor)

        # 모델 학습
        multi_output_voting_reg.fit(X_train_fold, y_train_fold)

        # 예측 및 평가
        y_pred_valid = multi_output_voting_reg.predict(X_val_fold)
        voting_val_rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_valid))

        if voting_val_rmse < best_valid_rmse:
            best_valid_rmse = voting_val_rmse
            voting_best_model = multi_output_voting_reg
            voting_best_train_input = X_train_fold
            voting_best_train_output = y_train_fold
            voting_best_valid_input = X_val_fold
            voting_best_valid_output = y_val_fold
            print(f'best rmse : {best_valid_rmse}')

    voting_pred = voting_best_model.predict(X_test_scaled)

    data_to_save = {
        Model.MODEL: voting_best_model,
        Data.TRAIN_INPUT_DATA: voting_best_train_input,
        Data.TRAIN_OUTPUT_DATA: voting_best_train_output,
        Data.VALID_INPUT_DATA: voting_best_valid_input,
        Data.VALID_OUTPUT_DATA: voting_best_valid_output,
        Data.TEST_INPUT_DATA: X_test_scaled,
        Data.TEST_OUTPUT_DATA: y_test,
        Data.PREDICTED_OUTPUT_DATA: voting_pred,
        Rmse.BEST_RMSE: np.sqrt(mean_squared_error(voting_pred, y_test)),
        Date.DATE: date_df,
    }

    # 조합 이름 생성 (모델 이름을 이어붙임)
    model_names = '_'.join([name for name, _ in subset])

    # 경로 및 파일 이름 설정
    path = f'result_model_fold/{area}'
    file_path = f'{path}/Voting_{model_names}_model_with_{area}.pkl'

    # 디렉토리 생성 및 파일 저장
    os.makedirs(path, exist_ok=True)
    with open(file_path, 'wb') as f:
        pickle.dump(data_to_save, f)

    print(f'Model saved to {file_path} with RMSE: {np.sqrt(mean_squared_error(voting_pred, y_test))}')
# Out:
# best rmse : 3.113669287716361
# best rmse : 3.0557413442776267
# best rmse : 2.937840670018237
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_model_with_Swanton_OH.pkl with RMSE: 3.0493504436645256
# best rmse : 2.977591118892199
# best rmse : 2.938946007549051
# best rmse : 2.822436103250354
# Model saved to result_model_fold/Swanton_OH/Voting_RF_MLP_model_with_Swanton_OH.pkl with RMSE: 2.9827219991324863
# best rmse : 3.265519712625574
# best rmse : 3.234224967186136
# best rmse : 3.21314498285454
# best rmse : 3.1931655516271125
# Model saved to result_model_fold/Swanton_OH/Voting_RF_DT_model_with_Swanton_OH.pkl with RMSE: 3.174962640896106
# best rmse : 2.9518474399902006
# best rmse : 2.93935957699915
# best rmse : 2.8196309600668714
# Model saved to result_model_fold/Swanton_OH/Voting_RF_XG_model_with_Swanton_OH.pkl with RMSE: 2.946191941754925
# best rmse : 3.058148904721537
# best rmse : 2.99402156400053
# best rmse : 2.879008887118971
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_MLP_model_with_Swanton_OH.pkl with RMSE: 3.051551095078065
# best rmse : 3.312021463879337
# best rmse : 3.251016367721884
# best rmse : 3.221089502615739
# best rmse : 3.217649698072621
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_DT_model_with_Swanton_OH.pkl with RMSE: 3.2076111057203844
# best rmse : 3.002378021403907
# best rmse : 2.962263456561631
# best rmse : 2.837288129679004
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_XG_model_with_Swanton_OH.pkl with RMSE: 2.9764692503561645
# best rmse : 3.176956766017157
# best rmse : 3.131605117689924
# best rmse : 3.1092134043328046
# best rmse : 3.099732187414636
# Model saved to result_model_fold/Swanton_OH/Voting_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.1453208475657615
# best rmse : 2.91196550007769
# best rmse : 2.893857380614012
# best rmse : 2.7781133807087586
# Model saved to result_model_fold/Swanton_OH/Voting_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.958166423643407
# best rmse : 3.1628356136965543
# best rmse : 3.150437067846968
# best rmse : 3.1247895147121283
# best rmse : 3.1045673642622584
# Model saved to result_model_fold/Swanton_OH/Voting_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.103170527977388
# best rmse : 3.0290535965618512
# best rmse : 2.9747173429204126
# best rmse : 2.8556692612228503
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_MLP_model_with_Swanton_OH.pkl with RMSE: 3.006987588022659
# best rmse : 3.181467354562989
# best rmse : 3.1323336651937064
# best rmse : 3.07142448808594
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_DT_model_with_Swanton_OH.pkl with RMSE: 3.161245783809207
# best rmse : 3.000112434034726
# best rmse : 2.9649540074339114
# best rmse : 2.8414291758706187
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_XG_model_with_Swanton_OH.pkl with RMSE: 2.9698230570892865
# best rmse : 3.0791593653893132
# best rmse : 3.0392097954581194
# best rmse : 2.9810507835738003
# Model saved to result_model_fold/Swanton_OH/Voting_RF_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.1036163769818095
# best rmse : 2.9175382901921307
# best rmse : 2.8942924402144143
# best rmse : 2.7737718965982388
# Model saved to result_model_fold/Swanton_OH/Voting_RF_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9348968566973643
# best rmse : 3.0687399689972876
# best rmse : 3.052123129349441
# best rmse : 2.9924384054114737
# Model saved to result_model_fold/Swanton_OH/Voting_RF_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.087300407260609
# best rmse : 3.1173214832897336
# best rmse : 3.05915255202414
# best rmse : 2.99708316727551
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.131218883225137
# best rmse : 2.957410987299442
# best rmse : 2.917228842592829
# best rmse : 2.7948755001576404
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9646329830345297
# best rmse : 3.0937446019613146
# best rmse : 3.0580912358892203
# best rmse : 2.99191756396758
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.098165096210105
# best rmse : 3.010229212241684
# best rmse : 2.9850193579103985
# best rmse : 2.9244403826152694
# Model saved to result_model_fold/Swanton_OH/Voting_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.0607084880978728
# best rmse : 3.076683168310276
# best rmse : 3.0259311624827965
# best rmse : 2.948259768011388
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_MLP_DT_model_with_Swanton_OH.pkl with RMSE: 3.0763004315079083
# best rmse : 2.9627295071716433
# best rmse : 2.924655873839505
# best rmse : 2.8017479086119055
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_MLP_XG_model_with_Swanton_OH.pkl with RMSE: 2.9565311155135454
# best rmse : 3.061038580619904
# best rmse : 3.0277512463602103
# best rmse : 2.9476807386277075
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.0554878723577925
# best rmse : 2.9903224289506523
# best rmse : 2.964143783989414
# best rmse : 2.886803511475428
# Model saved to result_model_fold/Swanton_OH/Voting_RF_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.0195022472290596
# best rmse : 3.0141752230998544
# best rmse : 2.974533050642637
# best rmse : 2.8936160999284812
# Model saved to result_model_fold/Swanton_OH/Voting_EXTRA_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.0346406612217867
# best rmse : 3.00613249539298
# best rmse : 2.9686489651570227
# best rmse : 2.879286546046371
# Model saved to result_model_fold/Swanton_OH/Voting_RF_EXTRA_MLP_DT_XG_model_with_Swanton_OH.pkl with RMSE: 3.0142844973765066
