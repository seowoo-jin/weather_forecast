# %%
import pickle
with open('result_model_fold/Swanton_OH/MLP_model_with_Swanton_OH.pkl', 'rb') as f:
    print(f)
    data = pickle.load(f)
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA], data[Data.TEST_OUTPUT_DATA].columns)
# Out:
# <_io.BufferedReader name='result_model_fold/Swanton_OH/MLP_model_with_Swanton_OH.pkl'>

# %%
import pickle
with open('result_model_fold/Billings_MT/MLP_model_with_Billings_MT.pkl', 'rb') as f:
    print(f)
    data = pickle.load(f)
from utils.monthly_rmse import monthlyRmsePlot
monthlyRmsePlot(data)
from utils.monthly_mae import monthlyMaePlot
monthlyMaePlot(data)
from enums.enums import Model, Date, Data, Rmse
from utils.create_plot import create_plot
create_plot(data[Data.TEST_OUTPUT_DATA].to_numpy(), data[Data.PREDICTED_OUTPUT_DATA], data[Data.TEST_OUTPUT_DATA].columns)
# Out:
# <_io.BufferedReader name='result_model_fold/Billings_MT/MLP_model_with_Billings_MT.pkl'>
